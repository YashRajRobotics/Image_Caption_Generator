# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os 
os.chdir('/content/gdrive/My Drive/College/Semester 6/Minor Project')

# %%
import tensorflow as tf

# %%
import string
import numpy as np
import pandas as pd 
from numpy import array
from PIL import Image
import pickle

import matplotlib.pyplot as plt
import keras
import sys, time, os, warnings 
warnings.filterwarnings("ignore")
import re

import tensorflow as tf
from tqdm import tqdm

from nltk.translate.bleu_score import sentence_bleu

from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense, BatchNormalization
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers.merge import add
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing.text import Tokenizer

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
# !nvidia-smi
# Out:
# Wed Jan 20 20:15:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
image_path = "Dataset/Flicker8k_Dataset"
dir_Flickr_text = "Dataset/Flickr_8k_text/Flickr8k.token.txt"

jpgs = os.listdir(image_path)
print("Total Images in Dataset = {}".format(len(jpgs)))
# Out:
# Total Images in Dataset = 9462

# %%
file = open(dir_Flickr_text,'r')
text = file.read()
file.close()

datatxt = []
for line in text.split('\n'):
    col = line.split('\t')
    if len(col) == 1:
        continue
    w = col[0].split("#")
    datatxt.append(w + [col[1].lower()])

data = pd.DataFrame(datatxt,columns=["filename","index","caption"])
data = data.reindex(columns =['index','filename','caption'])
data = data[data['filename'] != '2258277193_586949ec62.jpg.1']


uni_filenames = np.unique(data.filename.values)
data.head()
# Out:
#   index  ...                                            caption
# 0     0  ...  a child in a pink dress is climbing up a set o...
# 1     1  ...              a girl going into a wooden building .
# 2     2  ...   a little girl climbing into a wooden playhouse .
# 3     3  ...  a little girl climbing the stairs to her playh...
# 4     4  ...  a little girl in a pink dress going into a woo...
#
# [5 rows x 3 columns]

# %%
from keras.preprocessing.image import load_img, img_to_array

npic = 5
npix = 224
target_size = (npix,npix,3)

count = 1
fig = plt.figure(figsize=(10,20))
for jpgfnm in uni_filenames[10:15]:
    filename = image_path + '/' + jpgfnm
    captions = list(data["caption"].loc[data["filename"]==jpgfnm].values)
    image_load = load_img(filename, target_size=target_size)
    
    ax = fig.add_subplot(npic,2,count,xticks=[],yticks=[])
    ax.imshow(image_load)
    count += 1
    
    ax = fig.add_subplot(npic,2,count)
    plt.axis('off')
    ax.plot()
    ax.set_xlim(0,1)
    ax.set_ylim(0,len(captions))
    for i, caption in enumerate(captions):
        ax.text(0,i,caption,fontsize=20)
    count += 1
plt.show()

# %%
vocabulary = []
for txt in data.caption.values:
    vocabulary.extend(txt.split())
print('Vocabulary Size: %d' % len(set(vocabulary)))
# Out:
# Vocabulary Size: 8918

# %%
img = data["filename"].tolist()
caption = data["caption"].tolist()

# %%
print(f"len(img) : {len(img)}")
print(f"len(caption) : {len(caption)}")
# Out:
# len(img) : 40455
# len(caption) : 40455

# %%
def remove_punctuation(text_original):
    text_no_punctuation = text_original.translate(string.punctuation)
    return(text_no_punctuation)

def remove_single_character(text):
    text_len_more_than1 = ""
    for word in text.split():
        if len(word) > 1:
            text_len_more_than1 += " " + word
    return(text_len_more_than1)

def remove_numeric(text):
    text_no_numeric = ""
    for word in text.split():
        isalpha = word.isalpha()
        if isalpha:
            text_no_numeric += " " + word
    return(text_no_numeric)

# %%
def text_clean(text_original):
    text = remove_punctuation(text_original)
    text = remove_single_character(text)
    text = remove_numeric(text)
    return(text)
    
for i, caption in enumerate(data.caption.values):
    newcaption = text_clean(caption)
    data["caption"].iloc[i] = newcaption

# %%
clean_vocabulary = []
for txt in data.caption.values:
    clean_vocabulary.extend(txt.split())
print('Clean Vocabulary Size: %d' % len(set(clean_vocabulary)))
# Out:
# Clean Vocabulary Size: 8357

# %%
PATH = "/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/"
all_captions = []

for caption  in data["caption"].astype(str):
    caption = '<start> ' + caption+ ' <end>'
    all_captions.append(caption)
all_captions[:10]
# Out:
# ['<start>  child in pink dress is climbing up set of stairs in an entry way <end>',
#  '<start>  girl going into wooden building <end>',
#  '<start>  little girl climbing into wooden playhouse <end>',
#  '<start>  little girl climbing the stairs to her playhouse <end>',
#  '<start>  little girl in pink dress going into wooden cabin <end>',
#  '<start>  black dog and spotted dog are fighting <end>',
#  '<start>  black dog and dog playing with each other on the road <end>',
#  '<start>  black dog and white dog with brown spots are staring at each other in the street <end>',
#  '<start>  two dogs of different breeds looking at each other on the road <end>',
#  '<start>  two dogs on pavement moving toward each other <end>']

# %%
all_img_name_vector = []

for annot in data["filename"]:
    full_image_path = PATH + annot

    all_img_name_vector.append(full_image_path)
all_img_name_vector[:10]
# Out:
# ['/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/My Drive/College/Semester 6/Minor Project/Dataset/Flicker8k_Dataset/1001773457_577c3a7d70.jpg']

# %%
print(f"len(all_img_name_vector) : {len(all_img_name_vector)}")
print(f"len(all_captions) : {len(all_captions)}")
# Out:
# len(all_img_name_vector) : 40455
# len(all_captions) : 40455

# %%
def data_limiter(num,total_captions,all_img_name_vector):
    train_captions, img_name_vector = shuffle(total_captions,all_img_name_vector,random_state=1)
    train_captions = train_captions[:num]
    img_name_vector = img_name_vector[:num]
    return train_captions,img_name_vector

# %%
train_captions,img_name_vector = data_limiter(40000,all_captions,all_img_name_vector)

# %%
print(f"len(all_img_name_vector) : {len(img_name_vector)}")
print(f"len(all_captions) : {len(train_captions)}")
# Out:
# len(all_img_name_vector) : 40000
# len(all_captions) : 40000

# %% [markdown]
# ### Main Feature Extraction using **Inception_v3**

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img) 
    return img, image_path

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet') 
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
encode_train = sorted(set(img_name_vector))

image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

for img, path in tqdm(image_dataset):
    batch_features = image_features_extract_model(img) 
    batch_features = tf.reshape(batch_features, (batch_features.shape[0], -1, batch_features.shape[3]))

    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        np.save(path_of_feature, bf.numpy())
# Out:
# 100%|██████████| 506/506 [40:51<00:00,  4.85s/it]

# %% [markdown]
# ### Preprocess and tokenize the captions

# %%
top_k = 5000

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k, oov_token="<unk>", filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
cap_vector.shape
# Out:
# (40000, 33)

# %% [markdown]
# ### Split the data into training and testing

# %%
img_name_train, img_name_val, cap_train, cap_val = train_test_split(img_name_vector, cap_vector, test_size=0.2, random_state=0)

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (32000, 32000, 8000, 8000)

# %% [markdown]
# ### Create a tf.data dataset for training

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
num_steps = len(img_name_train) // BATCH_SIZE

# %%
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

dataset = dataset.map(lambda item1, item2: tf.numpy_function(map_func, [item1, item2], [tf.float32, tf.int32]),
                    num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

# %% [markdown]
# ### Transformers Encoding

# %%
def positional_encoding_1d(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis], np.arange(d_model)[np.newaxis, :], d_model)
    
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        
    pos_encoding = angle_rads[np.newaxis, ...]
        
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def positional_encoding_2d(row,col,d_model):
    assert d_model % 2 == 0
    row_pos = np.repeat(np.arange(row),col)[:,np.newaxis]
    col_pos = np.repeat(np.expand_dims(np.arange(col),0),row,axis=0).reshape(-1,1)
    angle_rads_row = get_angles(row_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
    angle_rads_col = get_angles(col_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
    angle_rads_row[:, 0::2] = np.sin(angle_rads_row[:, 0::2])
    angle_rads_row[:, 1::2] = np.cos(angle_rads_row[:, 1::2])
    angle_rads_col[:, 0::2] = np.sin(angle_rads_col[:, 0::2])
    angle_rads_col[:, 1::2] = np.cos(angle_rads_col[:, 1::2])
    pos_encoding = np.concatenate([angle_rads_row,angle_rads_col],axis=1)[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask

# %% [markdown]
# ### Feature products

# %%
def scaled_dot_product_attention(q, k, v, mask):
    
    matmul_qk = tf.matmul(q, k, transpose_b=True)   
    
    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    if mask is not None:
        scaled_attention_logits += (mask * -1e9)  

    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1) 

    output = tf.matmul(attention_weights, v) 

    return output, attention_weights

# %% [markdown]
# ### Multi-Headed attention

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        
        assert d_model % self.num_heads == 0
        
        self.depth = d_model // self.num_heads
        
        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)
        
        self.dense = tf.keras.layers.Dense(d_model)
        
    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])
    
    def call(self, v, k, q, mask=None):
        batch_size = tf.shape(q)[0]
        
        q = self.wq(q)   
        k = self.wk(k)  
        v = self.wv(v)  
        
        q = self.split_heads(q, batch_size)  
        k = self.split_heads(k, batch_size)  
        v = self.split_heads(v, batch_size)  
        
        scaled_attention, attention_weights = scaled_dot_product_attention(q, k, v, mask)
        
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3]) 

        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model)) 

        output = self.dense(concat_attention) 
        
        return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),  
        tf.keras.layers.Dense(d_model)  
    ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        
    def call(self, x, training, mask=None):

        attn_output, _ = self.mha(x, x, x, mask)  
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)  
        
        ffn_output = self.ffn(out1)  
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)  
        
        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)
    
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)
        
        
    def call(self, x, enc_output, training, look_ahead_mask=None, padding_mask=None):
        
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask) 
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)
        
        attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask)  
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)  
        
        ffn_output = self.ffn(out2) 
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2) 
        
        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, row_size,col_size,rate=0.1):
        super(Encoder, self).__init__()
        self.d_model = d_model
        self.num_layers = num_layers
        self.embedding = tf.keras.layers.Dense(self.d_model,activation='relu')
        self.pos_encoding = positional_encoding_2d(row_size,col_size, self.d_model)
        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)
            
    def call(self, x, training, mask=None):
        seq_len = tf.shape(x)[1]
        x = self.embedding(x)  
        x += self.pos_encoding[:, :seq_len, :]
        x = self.dropout(x, training=training)
        for i in range(self.num_layers):
        x = self.enc_layers[i](x, training, mask)
        return x

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size, maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()
        self.d_model = d_model
        self.num_layers = num_layers
        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding_1d(maximum_position_encoding, d_model)
        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)
        
    def call(self, x, enc_output, training, look_ahead_mask=None, padding_mask=None):

        seq_len = tf.shape(x)[1]
        attention_weights = {}
        x = self.embedding(x)  
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]
        x = self.dropout(x, training=training)
        for i in range(self.num_layers):
        x, block1, block2 = self.dec_layers[i](x, enc_output, training, look_ahead_mask, padding_mask)
        
        attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
        attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
        
        return x, attention_weights

# %%
class Transformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff,row_size,col_size, target_vocab_size,max_pos_encoding, rate=0.1):
        super(Transformer, self).__init__()

        self.encoder = Encoder(num_layers, d_model, num_heads, dff,row_size,col_size, rate)

        self.decoder = Decoder(num_layers, d_model, num_heads, dff, target_vocab_size,max_pos_encoding, rate)

        self.final_layer = tf.keras.layers.Dense(target_vocab_size)
        
    def call(self, inp, tar, training,look_ahead_mask=None, dec_padding_mask=None,enc_padding_mask=None):

        enc_output = self.encoder(inp, training, enc_padding_mask)  
        
        dec_output, attention_weights = self.decoder(tar, enc_output, training, look_ahead_mask, dec_padding_mask)
        
        final_output = self.final_layer(dec_output)  
        
        return final_output, attention_weights

# %%
num_layer = 4
d_model = 512
dff = 2048
num_heads = 8
row_size = 8
col_size = 8
target_vocab_size = top_k + 1
dropout_rate = 0.1

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()
        
        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps
        
    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)
        
        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    
    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

# %%
transformer = Transformer(num_layer,d_model,num_heads,dff,row_size,col_size,target_vocab_size,max_pos_encoding=target_vocab_size,rate=dropout_rate)

# %%
def create_masks_decoder(tar):
    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
    return combined_mask

# %%
@tf.function
def train_step(img_tensor, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]
    
    dec_mask = create_masks_decoder(tar_inp)
    
    with tf.GradientTape() as tape:
        predictions, _ = transformer(img_tensor, tar_inp, True, dec_mask)
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
    
    train_loss(loss)
    train_accuracy(tar_real, predictions)

# %%
for epoch in range(30):
    start = time.time()
    train_loss.reset_states()
    train_accuracy.reset_states()
    for (batch, (img_tensor, tar)) in enumerate(dataset):
        train_step(img_tensor, tar)
        if batch % 50 == 0:
            print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, batch, train_loss.result(), train_accuracy.result()))
    print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, train_loss.result(), train_accuracy.result()))          
    print ('Time taken for ' + str(epoch+1) + 'th epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 8.6163 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 8.1777 Accuracy 0.0199
# Epoch 1 Batch 100 Loss 7.7514 Accuracy 0.0255
# Epoch 1 Batch 150 Loss 7.4446 Accuracy 0.0279
# Epoch 1 Batch 200 Loss 7.1461 Accuracy 0.0307
# Epoch 1 Batch 250 Loss 6.8683 Accuracy 0.0343
# Epoch 1 Batch 300 Loss 6.6202 Accuracy 0.0379
# Epoch 1 Batch 350 Loss 6.4046 Accuracy 0.0416
# Epoch 1 Batch 400 Loss 6.2097 Accuracy 0.0452
# Epoch 1 Batch 450 Loss 6.0381 Accuracy 0.0485
# Epoch 1 Loss 5.8901 Accuracy 0.0514
# Time taken for 1 epoch: 1223.6955239772797 secs
#
# Epoch 2 Batch 0 Loss 4.5001 Accuracy 0.0767
# Epoch 2 Batch 50 Loss 4.3963 Accuracy 0.0812
# Epoch 2 Batch 100 Loss 4.3405 Accuracy 0.0825
# Epoch 2 Batch 150 Loss 4.2899 Accuracy 0.0832
# Epoch 2 Batch 200 Loss 4.2417 Accuracy 0.0840
# Epoch 2 Batch 250 Loss 4.1978 Accuracy 0.0852
# Epoch 2 Batch 300 Loss 4.1572 Accuracy 0.0861
# Epoch 2 Batch 350 Loss 4.1197 Accuracy 0.0870
# Epoch 2 Batch 400 Loss 4.0826 Accuracy 0.0878
# Epoch 2 Batch 450 Loss 4.0466 Accuracy 0.0885
# Epoch 2 Loss 4.0147 Accuracy 0.0893
# Time taken for 1 epoch: 126.81704092025757 secs
#
# Epoch 3 Batch 0 Loss 3.6274 Accuracy 0.1157
# Epoch 3 Batch 50 Loss 3.6769 Accuracy 0.0976
# Epoch 3 Batch 100 Loss 3.6620 Accuracy 0.0984
# Epoch 3 Batch 150 Loss 3.6395 Accuracy 0.0988
# Epoch 3 Batch 200 Loss 3.6109 Accuracy 0.0992
# Epoch 3 Batch 250 Loss 3.5939 Accuracy 0.0996
# Epoch 3 Batch 300 Loss 3.5803 Accuracy 0.1000
# Epoch 3 Batch 350 Loss 3.5650 Accuracy 0.1003
# Epoch 3 Batch 400 Loss 3.5460 Accuracy 0.1007
# Epoch 3 Batch 450 Loss 3.5293 Accuracy 0.1012
# Epoch 3 Loss 3.5166 Accuracy 0.1014
# Time taken for 1 epoch: 126.29356980323792 secs
#
# Epoch 4 Batch 0 Loss 3.4115 Accuracy 0.1021
# Epoch 4 Batch 50 Loss 3.3549 Accuracy 0.1057
# Epoch 4 Batch 100 Loss 3.3423 Accuracy 0.1068
# Epoch 4 Batch 150 Loss 3.3269 Accuracy 0.1069
# Epoch 4 Batch 200 Loss 3.3175 Accuracy 0.1067
# Epoch 4 Batch 250 Loss 3.3127 Accuracy 0.1070
# Epoch 4 Batch 300 Loss 3.3025 Accuracy 0.1072
# Epoch 4 Batch 350 Loss 3.2911 Accuracy 0.1076
# Epoch 4 Batch 400 Loss 3.2794 Accuracy 0.1077
# Epoch 4 Batch 450 Loss 3.2692 Accuracy 0.1080
# Epoch 4 Loss 3.2610 Accuracy 0.1083
# Time taken for 1 epoch: 126.51346397399902 secs
#
# Epoch 5 Batch 0 Loss 3.0929 Accuracy 0.1040
# Epoch 5 Batch 50 Loss 3.1504 Accuracy 0.1117
# Epoch 5 Batch 100 Loss 3.1516 Accuracy 0.1125
# Epoch 5 Batch 150 Loss 3.1453 Accuracy 0.1122
# Epoch 5 Batch 200 Loss 3.1333 Accuracy 0.1119
# Epoch 5 Batch 250 Loss 3.1268 Accuracy 0.1124
# Epoch 5 Batch 300 Loss 3.1210 Accuracy 0.1126
# Epoch 5 Batch 350 Loss 3.1126 Accuracy 0.1128
# Epoch 5 Batch 400 Loss 3.1057 Accuracy 0.1129
# Epoch 5 Batch 450 Loss 3.0962 Accuracy 0.1132
# Epoch 5 Loss 3.0916 Accuracy 0.1133
# Time taken for 1 epoch: 127.2948887348175 secs
#
# Epoch 6 Batch 0 Loss 2.8904 Accuracy 0.1172
# Epoch 6 Batch 50 Loss 3.0257 Accuracy 0.1159
# Epoch 6 Batch 100 Loss 3.0176 Accuracy 0.1166
# Epoch 6 Batch 150 Loss 3.0120 Accuracy 0.1163
# Epoch 6 Batch 200 Loss 3.0068 Accuracy 0.1158
# Epoch 6 Batch 250 Loss 3.0020 Accuracy 0.1160
# Epoch 6 Batch 300 Loss 2.9955 Accuracy 0.1162
# Epoch 6 Batch 350 Loss 2.9909 Accuracy 0.1162
# Epoch 6 Batch 400 Loss 2.9823 Accuracy 0.1164
# Epoch 6 Batch 450 Loss 2.9768 Accuracy 0.1166
# Epoch 6 Loss 2.9730 Accuracy 0.1168
# Time taken for 1 epoch: 126.65335464477539 secs
#
# Epoch 7 Batch 0 Loss 2.9169 Accuracy 0.1123
# Epoch 7 Batch 50 Loss 2.9240 Accuracy 0.1184
# Epoch 7 Batch 100 Loss 2.9245 Accuracy 0.1188
# Epoch 7 Batch 150 Loss 2.9206 Accuracy 0.1188
# Epoch 7 Batch 200 Loss 2.9175 Accuracy 0.1184
# Epoch 7 Batch 250 Loss 2.9138 Accuracy 0.1184
# Epoch 7 Batch 300 Loss 2.9087 Accuracy 0.1187
# Epoch 7 Batch 350 Loss 2.9068 Accuracy 0.1188
# Epoch 7 Batch 400 Loss 2.9010 Accuracy 0.1186
# Epoch 7 Batch 450 Loss 2.8979 Accuracy 0.1188
# Epoch 7 Loss 2.8963 Accuracy 0.1188
# Time taken for 1 epoch: 127.16371965408325 secs
#
# Epoch 8 Batch 0 Loss 2.7621 Accuracy 0.1187
# Epoch 8 Batch 50 Loss 2.8645 Accuracy 0.1190
# Epoch 8 Batch 100 Loss 2.8621 Accuracy 0.1205
# Epoch 8 Batch 150 Loss 2.8624 Accuracy 0.1200
# Epoch 8 Batch 200 Loss 2.8630 Accuracy 0.1197
# Epoch 8 Batch 250 Loss 2.8649 Accuracy 0.1195
# Epoch 8 Batch 300 Loss 2.8639 Accuracy 0.1196
# Epoch 8 Batch 350 Loss 2.8606 Accuracy 0.1196
# Epoch 8 Batch 400 Loss 2.8591 Accuracy 0.1194
# Epoch 8 Batch 450 Loss 2.8554 Accuracy 0.1196
# Epoch 8 Loss 2.8562 Accuracy 0.1194
# Time taken for 1 epoch: 126.8099672794342 secs
#
# Epoch 9 Batch 0 Loss 2.8201 Accuracy 0.1270
# Epoch 9 Batch 50 Loss 2.8595 Accuracy 0.1188
# Epoch 9 Batch 100 Loss 2.8405 Accuracy 0.1202
# Epoch 9 Batch 150 Loss 2.8360 Accuracy 0.1204
# Epoch 9 Batch 200 Loss 2.8297 Accuracy 0.1199
# Epoch 9 Batch 250 Loss 2.8269 Accuracy 0.1199
# Epoch 9 Batch 300 Loss 2.8244 Accuracy 0.1200
# Epoch 9 Batch 350 Loss 2.8156 Accuracy 0.1202
# Epoch 9 Batch 400 Loss 2.8076 Accuracy 0.1202
# Epoch 9 Batch 450 Loss 2.7989 Accuracy 0.1206
# Epoch 9 Loss 2.7934 Accuracy 0.1208
# Time taken for 1 epoch: 127.45472621917725 secs
#
# Epoch 10 Batch 0 Loss 2.6749 Accuracy 0.1265
# Epoch 10 Batch 50 Loss 2.7251 Accuracy 0.1240
# Epoch 10 Batch 100 Loss 2.7104 Accuracy 0.1255
# Epoch 10 Batch 150 Loss 2.7088 Accuracy 0.1248
# Epoch 10 Batch 200 Loss 2.7071 Accuracy 0.1246
# Epoch 10 Batch 250 Loss 2.7034 Accuracy 0.1247
# Epoch 10 Batch 300 Loss 2.6963 Accuracy 0.1251
# Epoch 10 Batch 350 Loss 2.6913 Accuracy 0.1252
# Epoch 10 Batch 400 Loss 2.6826 Accuracy 0.1252
# Epoch 10 Batch 450 Loss 2.6756 Accuracy 0.1256
# Epoch 10 Loss 2.6699 Accuracy 0.1258
# Time taken for 1 epoch: 126.61928176879883 secs
#
# Epoch 11 Batch 0 Loss 2.6796 Accuracy 0.1191
# Epoch 11 Batch 50 Loss 2.6143 Accuracy 0.1279
# Epoch 11 Batch 100 Loss 2.6015 Accuracy 0.1291
# Epoch 11 Batch 150 Loss 2.5957 Accuracy 0.1285
# Epoch 11 Batch 200 Loss 2.5928 Accuracy 0.1286
# Epoch 11 Batch 250 Loss 2.5876 Accuracy 0.1286
# Epoch 11 Batch 300 Loss 2.5835 Accuracy 0.1288
# Epoch 11 Batch 350 Loss 2.5766 Accuracy 0.1291
# Epoch 11 Batch 400 Loss 2.5703 Accuracy 0.1291
# Epoch 11 Batch 450 Loss 2.5624 Accuracy 0.1296
# Epoch 11 Loss 2.5576 Accuracy 0.1297
# Time taken for 1 epoch: 127.7924292087555 secs
#
# Epoch 12 Batch 0 Loss 2.3952 Accuracy 0.1348
# Epoch 12 Batch 50 Loss 2.4995 Accuracy 0.1316
# Epoch 12 Batch 100 Loss 2.4946 Accuracy 0.1331
# Epoch 12 Batch 150 Loss 2.4872 Accuracy 0.1331
# Epoch 12 Batch 200 Loss 2.4801 Accuracy 0.1329
# Epoch 12 Batch 250 Loss 2.4770 Accuracy 0.1330
# Epoch 12 Batch 300 Loss 2.4713 Accuracy 0.1332
# Epoch 12 Batch 350 Loss 2.4667 Accuracy 0.1334
# Epoch 12 Batch 400 Loss 2.4596 Accuracy 0.1336
# Epoch 12 Batch 450 Loss 2.4527 Accuracy 0.1340
# Epoch 12 Loss 2.4489 Accuracy 0.1343
# Time taken for 1 epoch: 127.08063650131226 secs
#
# Epoch 13 Batch 0 Loss 2.5218 Accuracy 0.1221
# Epoch 13 Batch 50 Loss 2.3960 Accuracy 0.1358
# Epoch 13 Batch 100 Loss 2.3911 Accuracy 0.1374
# Epoch 13 Batch 150 Loss 2.3886 Accuracy 0.1367
# Epoch 13 Batch 200 Loss 2.3788 Accuracy 0.1368
# Epoch 13 Batch 250 Loss 2.3767 Accuracy 0.1368
# Epoch 13 Batch 300 Loss 2.3696 Accuracy 0.1373
# Epoch 13 Batch 350 Loss 2.3640 Accuracy 0.1375
# Epoch 13 Batch 400 Loss 2.3571 Accuracy 0.1378
# Epoch 13 Batch 450 Loss 2.3514 Accuracy 0.1380
# Epoch 13 Loss 2.3462 Accuracy 0.1383
# Time taken for 1 epoch: 127.66675090789795 secs
#
# Epoch 14 Batch 0 Loss 2.3086 Accuracy 0.1387
# Epoch 14 Batch 50 Loss 2.3038 Accuracy 0.1404
# Epoch 14 Batch 100 Loss 2.2930 Accuracy 0.1414
# Epoch 14 Batch 150 Loss 2.2912 Accuracy 0.1413
# Epoch 14 Batch 200 Loss 2.2849 Accuracy 0.1411
# Epoch 14 Batch 250 Loss 2.2807 Accuracy 0.1414
# Epoch 14 Batch 300 Loss 2.2754 Accuracy 0.1418
# Epoch 14 Batch 350 Loss 2.2669 Accuracy 0.1423
# Epoch 14 Batch 400 Loss 2.2607 Accuracy 0.1423
# Epoch 14 Batch 450 Loss 2.2561 Accuracy 0.1426
# Epoch 14 Loss 2.2509 Accuracy 0.1428
# Time taken for 1 epoch: 127.14913558959961 secs
#
# Epoch 15 Batch 0 Loss 2.1185 Accuracy 0.1431
# Epoch 15 Batch 50 Loss 2.1946 Accuracy 0.1462
# Epoch 15 Batch 100 Loss 2.1976 Accuracy 0.1467
# Epoch 15 Batch 150 Loss 2.1897 Accuracy 0.1463
# Epoch 15 Batch 200 Loss 2.1839 Accuracy 0.1457
# Epoch 15 Batch 250 Loss 2.1802 Accuracy 0.1458
# Epoch 15 Batch 300 Loss 2.1774 Accuracy 0.1460
# Epoch 15 Batch 350 Loss 2.1727 Accuracy 0.1462
# Epoch 15 Batch 400 Loss 2.1661 Accuracy 0.1464
# Epoch 15 Batch 450 Loss 2.1598 Accuracy 0.1469
# Epoch 15 Loss 2.1570 Accuracy 0.1469
# Time taken for 1 epoch: 127.99435257911682 secs
#
# Epoch 16 Batch 0 Loss 2.0395 Accuracy 0.1470
# Epoch 16 Batch 50 Loss 2.1052 Accuracy 0.1491
# Epoch 16 Batch 100 Loss 2.1075 Accuracy 0.1504
# Epoch 16 Batch 150 Loss 2.0986 Accuracy 0.1504
# Epoch 16 Batch 200 Loss 2.0896 Accuracy 0.1504
# Epoch 16 Batch 250 Loss 2.0859 Accuracy 0.1507
# Epoch 16 Batch 300 Loss 2.0830 Accuracy 0.1509
# Epoch 16 Batch 350 Loss 2.0803 Accuracy 0.1511
# Epoch 16 Batch 400 Loss 2.0746 Accuracy 0.1512
# Epoch 16 Batch 450 Loss 2.0692 Accuracy 0.1515
# Epoch 16 Loss 2.0657 Accuracy 0.1516
# Time taken for 1 epoch: 127.44262170791626 secs
#
# Epoch 17 Batch 0 Loss 2.0420 Accuracy 0.1484
# Epoch 17 Batch 50 Loss 2.0230 Accuracy 0.1528
# Epoch 17 Batch 100 Loss 2.0156 Accuracy 0.1538
# Epoch 17 Batch 150 Loss 2.0137 Accuracy 0.1539
# Epoch 17 Batch 200 Loss 2.0063 Accuracy 0.1538
# Epoch 17 Batch 250 Loss 2.0037 Accuracy 0.1540
# Epoch 17 Batch 300 Loss 1.9996 Accuracy 0.1545
# Epoch 17 Batch 350 Loss 1.9956 Accuracy 0.1547
# Epoch 17 Batch 400 Loss 1.9892 Accuracy 0.1549
# Epoch 17 Batch 450 Loss 1.9839 Accuracy 0.1552
# Epoch 17 Loss 1.9803 Accuracy 0.1554
# Time taken for 1 epoch: 127.7083387374878 secs
#
# Epoch 18 Batch 0 Loss 1.9941 Accuracy 0.1450
# Epoch 18 Batch 50 Loss 1.9429 Accuracy 0.1577
# Epoch 18 Batch 100 Loss 1.9379 Accuracy 0.1585
# Epoch 18 Batch 150 Loss 1.9279 Accuracy 0.1584
# Epoch 18 Batch 200 Loss 1.9256 Accuracy 0.1584
# Epoch 18 Batch 250 Loss 1.9228 Accuracy 0.1587
# Epoch 18 Batch 300 Loss 1.9198 Accuracy 0.1590
# Epoch 18 Batch 350 Loss 1.9145 Accuracy 0.1593
# Epoch 18 Batch 400 Loss 1.9087 Accuracy 0.1595
# Epoch 18 Batch 450 Loss 1.9045 Accuracy 0.1595
# Epoch 18 Loss 1.8997 Accuracy 0.1598
# Time taken for 1 epoch: 127.23378014564514 secs
#
# Epoch 19 Batch 0 Loss 1.8716 Accuracy 0.1514
# Epoch 19 Batch 50 Loss 1.8726 Accuracy 0.1613
# Epoch 19 Batch 100 Loss 1.8597 Accuracy 0.1631
# Epoch 19 Batch 150 Loss 1.8513 Accuracy 0.1632
# Epoch 19 Batch 200 Loss 1.8444 Accuracy 0.1632
# Epoch 19 Batch 250 Loss 1.8417 Accuracy 0.1633
# Epoch 19 Batch 300 Loss 1.8383 Accuracy 0.1635
# Epoch 19 Batch 350 Loss 1.8337 Accuracy 0.1639
# Epoch 19 Batch 400 Loss 1.8289 Accuracy 0.1638
# Epoch 19 Batch 450 Loss 1.8243 Accuracy 0.1642
# Epoch 19 Loss 1.8211 Accuracy 0.1642
# Time taken for 1 epoch: 127.95981740951538 secs
#
# Epoch 20 Batch 0 Loss 1.7861 Accuracy 0.1504
# Epoch 20 Batch 50 Loss 1.7898 Accuracy 0.1660
# Epoch 20 Batch 100 Loss 1.7815 Accuracy 0.1674
# Epoch 20 Batch 150 Loss 1.7690 Accuracy 0.1678
# Epoch 20 Batch 200 Loss 1.7648 Accuracy 0.1674
# Epoch 20 Batch 250 Loss 1.7651 Accuracy 0.1675
# Epoch 20 Batch 300 Loss 1.7627 Accuracy 0.1678
# Epoch 20 Batch 350 Loss 1.7616 Accuracy 0.1679
# Epoch 20 Batch 400 Loss 1.7579 Accuracy 0.1679
# Epoch 20 Batch 450 Loss 1.7529 Accuracy 0.1682
# Epoch 20 Loss 1.7489 Accuracy 0.1683
# Time taken for 1 epoch: 127.09639072418213 secs
#
# Epoch 21 Batch 0 Loss 1.7029 Accuracy 0.1768
# Epoch 21 Batch 50 Loss 1.7242 Accuracy 0.1687
# Epoch 21 Batch 100 Loss 1.7184 Accuracy 0.1699
# Epoch 21 Batch 150 Loss 1.7100 Accuracy 0.1704
# Epoch 21 Batch 200 Loss 1.7034 Accuracy 0.1700
# Epoch 21 Batch 250 Loss 1.6995 Accuracy 0.1706
# Epoch 21 Batch 300 Loss 1.6935 Accuracy 0.1713
# Epoch 21 Batch 350 Loss 1.6896 Accuracy 0.1713
# Epoch 21 Batch 400 Loss 1.6848 Accuracy 0.1716
# Epoch 21 Batch 450 Loss 1.6826 Accuracy 0.1716
# Epoch 21 Loss 1.6791 Accuracy 0.1720
# Time taken for 1 epoch: 127.93008494377136 secs
#
# Epoch 22 Batch 0 Loss 1.5633 Accuracy 0.1870
# Epoch 22 Batch 50 Loss 1.6471 Accuracy 0.1755
# Epoch 22 Batch 100 Loss 1.6450 Accuracy 0.1757
# Epoch 22 Batch 150 Loss 1.6404 Accuracy 0.1753
# Epoch 22 Batch 200 Loss 1.6377 Accuracy 0.1749
# Epoch 22 Batch 250 Loss 1.6348 Accuracy 0.1751
# Epoch 22 Batch 300 Loss 1.6314 Accuracy 0.1755
# Epoch 22 Batch 350 Loss 1.6277 Accuracy 0.1755
# Epoch 22 Batch 400 Loss 1.6229 Accuracy 0.1757
# Epoch 22 Batch 450 Loss 1.6197 Accuracy 0.1759
# Epoch 22 Loss 1.6170 Accuracy 0.1760
# Time taken for 1 epoch: 126.88257122039795 secs
#
# Epoch 23 Batch 0 Loss 1.6408 Accuracy 0.1631
# Epoch 23 Batch 50 Loss 1.5828 Accuracy 0.1785
# Epoch 23 Batch 100 Loss 1.5677 Accuracy 0.1804
# Epoch 23 Batch 150 Loss 1.5653 Accuracy 0.1801
# Epoch 23 Batch 200 Loss 1.5592 Accuracy 0.1798
# Epoch 23 Batch 250 Loss 1.5617 Accuracy 0.1797
# Epoch 23 Batch 300 Loss 1.5587 Accuracy 0.1801
# Epoch 23 Batch 350 Loss 1.5553 Accuracy 0.1803
# Epoch 23 Batch 400 Loss 1.5516 Accuracy 0.1804
# Epoch 23 Batch 450 Loss 1.5478 Accuracy 0.1806
# Epoch 23 Loss 1.5446 Accuracy 0.1807
# Time taken for 1 epoch: 127.71604132652283 secs
#
# Epoch 24 Batch 0 Loss 1.5707 Accuracy 0.1694
# Epoch 24 Batch 50 Loss 1.5236 Accuracy 0.1830
# Epoch 24 Batch 100 Loss 1.5148 Accuracy 0.1840
# Epoch 24 Batch 150 Loss 1.5118 Accuracy 0.1834
# Epoch 24 Batch 200 Loss 1.5059 Accuracy 0.1835
# Epoch 24 Batch 250 Loss 1.5051 Accuracy 0.1834
# Epoch 24 Batch 300 Loss 1.5024 Accuracy 0.1836
# Epoch 24 Batch 350 Loss 1.4986 Accuracy 0.1837
# Epoch 24 Batch 400 Loss 1.4967 Accuracy 0.1839
# Epoch 24 Batch 450 Loss 1.4928 Accuracy 0.1841
# Epoch 24 Loss 1.4884 Accuracy 0.1843
# Time taken for 1 epoch: 127.33224630355835 secs
#
# Epoch 25 Batch 0 Loss 1.4612 Accuracy 0.1943
# Epoch 25 Batch 50 Loss 1.4538 Accuracy 0.1868
# Epoch 25 Batch 100 Loss 1.4531 Accuracy 0.1872
# Epoch 25 Batch 150 Loss 1.4479 Accuracy 0.1871
# Epoch 25 Batch 200 Loss 1.4466 Accuracy 0.1866
# Epoch 25 Batch 250 Loss 1.4461 Accuracy 0.1870
# Epoch 25 Batch 300 Loss 1.4402 Accuracy 0.1877
# Epoch 25 Batch 350 Loss 1.4375 Accuracy 0.1878
# Epoch 25 Batch 400 Loss 1.4358 Accuracy 0.1877
# Epoch 25 Batch 450 Loss 1.4326 Accuracy 0.1879
# Epoch 25 Loss 1.4293 Accuracy 0.1881
# Time taken for 1 epoch: 128.0558021068573 secs
#
# Epoch 26 Batch 0 Loss 1.5689 Accuracy 0.1919
# Epoch 26 Batch 50 Loss 1.4041 Accuracy 0.1906
# Epoch 26 Batch 100 Loss 1.3982 Accuracy 0.1916
# Epoch 26 Batch 150 Loss 1.3933 Accuracy 0.1917
# Epoch 26 Batch 200 Loss 1.3914 Accuracy 0.1912
# Epoch 26 Batch 250 Loss 1.3890 Accuracy 0.1914
# Epoch 26 Batch 300 Loss 1.3857 Accuracy 0.1917
# Epoch 26 Batch 350 Loss 1.3824 Accuracy 0.1919
# Epoch 26 Batch 400 Loss 1.3790 Accuracy 0.1921
# Epoch 26 Batch 450 Loss 1.3762 Accuracy 0.1922
# Epoch 26 Loss 1.3744 Accuracy 0.1923
# Time taken for 1 epoch: 127.43978714942932 secs
#
# Epoch 27 Batch 0 Loss 1.3288 Accuracy 0.1865
# Epoch 27 Batch 50 Loss 1.3554 Accuracy 0.1941
# Epoch 27 Batch 100 Loss 1.3489 Accuracy 0.1941
# Epoch 27 Batch 150 Loss 1.3467 Accuracy 0.1945
# Epoch 27 Batch 200 Loss 1.3410 Accuracy 0.1945
# Epoch 27 Batch 250 Loss 1.3393 Accuracy 0.1949
# Epoch 27 Batch 300 Loss 1.3350 Accuracy 0.1952
# Epoch 27 Batch 350 Loss 1.3322 Accuracy 0.1953
# Epoch 27 Batch 400 Loss 1.3307 Accuracy 0.1954
# Epoch 27 Batch 450 Loss 1.3292 Accuracy 0.1953
# Epoch 27 Loss 1.3265 Accuracy 0.1956
# Time taken for 1 epoch: 128.35126948356628 secs
#
# Epoch 28 Batch 0 Loss 1.2669 Accuracy 0.1880
# Epoch 28 Batch 50 Loss 1.2997 Accuracy 0.1987
# Epoch 28 Batch 100 Loss 1.2999 Accuracy 0.1981
# Epoch 28 Batch 150 Loss 1.2956 Accuracy 0.1981
# Epoch 28 Batch 200 Loss 1.2891 Accuracy 0.1983
# Epoch 28 Batch 250 Loss 1.2897 Accuracy 0.1982
# Epoch 28 Batch 300 Loss 1.2849 Accuracy 0.1985
# Epoch 28 Batch 350 Loss 1.2822 Accuracy 0.1986
# Epoch 28 Batch 400 Loss 1.2790 Accuracy 0.1988
# Epoch 28 Batch 450 Loss 1.2773 Accuracy 0.1989
# Epoch 28 Loss 1.2743 Accuracy 0.1991
# Time taken for 1 epoch: 127.62817883491516 secs
#
# Epoch 29 Batch 0 Loss 1.2093 Accuracy 0.1978
# Epoch 29 Batch 50 Loss 1.2645 Accuracy 0.2002
# Epoch 29 Batch 100 Loss 1.2535 Accuracy 0.2020
# Epoch 29 Batch 150 Loss 1.2509 Accuracy 0.2017
# Epoch 29 Batch 200 Loss 1.2441 Accuracy 0.2015
# Epoch 29 Batch 250 Loss 1.2423 Accuracy 0.2020
# Epoch 29 Batch 300 Loss 1.2370 Accuracy 0.2025
# Epoch 29 Batch 350 Loss 1.2356 Accuracy 0.2025
# Epoch 29 Batch 400 Loss 1.2324 Accuracy 0.2025
# Epoch 29 Batch 450 Loss 1.2301 Accuracy 0.2027
# Epoch 29 Loss 1.2275 Accuracy 0.2030
# Time taken for 1 epoch: 127.53002452850342 secs
#
# Epoch 30 Batch 0 Loss 1.2277 Accuracy 0.1978
# Epoch 30 Batch 50 Loss 1.2158 Accuracy 0.2039
# Epoch 30 Batch 100 Loss 1.2103 Accuracy 0.2048
# Epoch 30 Batch 150 Loss 1.2082 Accuracy 0.2046
# Epoch 30 Batch 200 Loss 1.2025 Accuracy 0.2044
# Epoch 30 Batch 250 Loss 1.2008 Accuracy 0.2048
# Epoch 30 Batch 300 Loss 1.1967 Accuracy 0.2053
# Epoch 30 Batch 350 Loss 1.1934 Accuracy 0.2055
# Epoch 30 Batch 400 Loss 1.1915 Accuracy 0.2056
# Epoch 30 Batch 450 Loss 1.1886 Accuracy 0.2058
# Epoch 30 Loss 1.1862 Accuracy 0.2058
# Time taken for 1 epoch: 127.37493467330933 secs

# %%
transformer.save_weights('image_caption_transformer_45.h5')

# %%
def evaluate(image):

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))
    
    start_token = tokenizer.word_index['<start>']
    end_token = tokenizer.word_index['<end>']
    
    decoder_input = [start_token]
    output = tf.expand_dims(decoder_input, 0)  
    result = [] 

    for i in range(100):
        dec_mask = create_masks_decoder(output)
    
        predictions, attention_weights = transformer(img_tensor_val,output,False,dec_mask)
        
        predictions = predictions[: ,-1:, :]  

        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)
        if predicted_id == end_token:
            return result,tf.squeeze(output, axis=0), attention_weights
        result.append(tokenizer.index_word[int(predicted_id)])
        output = tf.concat([output, predicted_id], axis=-1)

    return result,tf.squeeze(output, axis=0), attention_weights

# %% [markdown]
# # Evaluation

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 33.33333333333333
# BLEU-2 score: 57.735026918962575
# BLEU-3 score: 71.92230933248644
# BLEU-4 score: 75.98356856515926
# Real Caption: boy in tie dyed shirt is riding skateboard down railing
# Predicted Caption: the boy is skateboarding on the railing in front of the building

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 12.113791079679324
# BLEU-2 score: 7.819418518505664
# BLEU-3 score: 11.427630951884652
# BLEU-4 score: 12.564686114779072
# Real Caption: small white dog is jumping over branch on the ground covered with leaves
# Predicted Caption: dog is running through leaves

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 32.206169703226536
# BLEU-2 score: 20.084075461628778
# BLEU-3 score: 34.04689031443354
# BLEU-4 score: 38.84935863283276
# Real Caption: closeup of young boy swimming in pool of water
# Predicted Caption: boy in pool tilts his head back

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 12.500000000000004
# BLEU-2 score: 35.35533905932738
# BLEU-3 score: 53.588673126814655
# BLEU-4 score: 59.46035575013605
# Real Caption: skateboarder wearing green shirt jumping on ramp
# Predicted Caption: skateboarder does jump in front of city building

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 6.062469223956427
# BLEU-2 score: 16.03978589757145
# BLEU-3 score: 23.671085545358732
# BLEU-4 score: 26.089939795640397
# Real Caption: the black and white dog along with the brown dog are galloping outside
# Predicted Caption: two dogs are running in grassy field

# %% [markdown]
# # Inference

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os 
os.chdir('/content/gdrive/My Drive/College/Semester 6/Lab/Minor Project')

# %%
import tensorflow as tf

# %%
import string
import numpy as np
import pandas as pd 
from numpy import array
from PIL import Image
import pickle

import matplotlib.pyplot as plt
import keras
import sys, time, os, warnings 
warnings.filterwarnings("ignore")
import re

import tensorflow as tf
from tqdm import tqdm

from nltk.translate.bleu_score import sentence_bleu

from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense, BatchNormalization
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers.merge import add
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing.text import Tokenizer

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
num_layer = 4
d_model = 512
dff = 2048
num_heads = 8
row_size = 8
col_size = 8
target_vocab_size = 5000 + 1
dropout_rate = 0.1

# %%
def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([tf.keras.layers.Dense(dff, activation='relu'), tf.keras.layers.Dense(d_model)])

# %%
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

# %%
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

# %%
def positional_encoding_1d(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis], np.arange(d_model)[np.newaxis, :], d_model)
    
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        
    pos_encoding = angle_rads[np.newaxis, ...]
        
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def positional_encoding_2d(row,col,d_model):
    assert d_model % 2 == 0
    row_pos = np.repeat(np.arange(row),col)[:,np.newaxis]
    col_pos = np.repeat(np.expand_dims(np.arange(col),0),row,axis=0).reshape(-1,1)
    angle_rads_row = get_angles(row_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
    angle_rads_col = get_angles(col_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
    angle_rads_row[:, 0::2] = np.sin(angle_rads_row[:, 0::2])
    angle_rads_row[:, 1::2] = np.cos(angle_rads_row[:, 1::2])
    angle_rads_col[:, 0::2] = np.sin(angle_rads_col[:, 0::2])
    angle_rads_col[:, 1::2] = np.cos(angle_rads_col[:, 1::2])
    pos_encoding = np.concatenate([angle_rads_row,angle_rads_col],axis=1)[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    
    return seq[:, tf.newaxis, tf.newaxis, :]

# %%
def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask

# %%
def scaled_dot_product_attention(q, k, v, mask):
 
    matmul_qk = tf.matmul(q, k, transpose_b=True) 
    
    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    if mask is not None:
        scaled_attention_logits += (mask * -1e9)  

    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)   

    output = tf.matmul(attention_weights, v)  

    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        
        assert d_model % self.num_heads == 0
        
        self.depth = d_model // self.num_heads
        
        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)
        
        self.dense = tf.keras.layers.Dense(d_model)
            
    def split_heads(self, x, batch_size):
       
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])
        
    def call(self, v, k, q, mask=None):
        batch_size = tf.shape(q)[0]
        
        q = self.wq(q)   
        k = self.wk(k)  
        v = self.wv(v)  
        
        q = self.split_heads(q, batch_size)   
        k = self.split_heads(k, batch_size)  
        v = self.split_heads(v, batch_size)  
        
        scaled_attention, attention_weights = scaled_dot_product_attention(q, k, v, mask)
        
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3]) 

        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model)) 

        output = self.dense(concat_attention)
            
        return output, attention_weights

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        
    def call(self, x, training, mask=None):

        attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
        
        ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
        
        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)
    
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)
        
        
    def call(self, x, enc_output, training, 
            look_ahead_mask=None, padding_mask=None):
        # enc_output.shape == (batch_size, input_seq_len, d_model)

        # using look ahead mask so that during self attention current query dont consider future token
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)
        
        # use padding mask to avoid padded values of both enc_output and dec_input
        attn2, attn_weights_block2 = self.mha2(
            enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)
        
        ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)
        
        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff,
                row_size,col_size,rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers
        
        self.embedding = tf.keras.layers.Dense(self.d_model,activation='relu')
        self.pos_encoding = positional_encoding_2d(row_size,col_size, 
                                                self.d_model)
        
        
        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                        for _ in range(num_layers)]
    
        self.dropout = tf.keras.layers.Dropout(rate)
            
    def call(self, x, training, mask=None):
        # shape(x) = (batch_size,seq_len(H*W),features)
        seq_len = tf.shape(x)[1]
        
        # adding embedding and position encoding.
        x = self.embedding(x)  # (batch_size, input_seq_len(H*W), d_model)
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)
        
        for i in range(self.num_layers):
        x = self.enc_layers[i](x, training, mask)
        
        return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
                maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers
        
        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding_1d(maximum_position_encoding, d_model)
        
        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                        for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)
        
    def call(self, x, enc_output, training, 
            look_ahead_mask=None, padding_mask=None):

        seq_len = tf.shape(x)[1]
        attention_weights = {}
        
        x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]
        
        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
        x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                                look_ahead_mask, padding_mask)
        
        attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
        attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
        
        # x.shape == (batch_size, target_seq_len, d_model)
        return x, attention_weights

# %%
class Transformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff,row_size,col_size, 
                target_vocab_size,max_pos_encoding, rate=0.1):
        super(Transformer, self).__init__()

        self.encoder = Encoder(num_layers, d_model, num_heads, dff,row_size,col_size, rate)

        self.decoder = Decoder(num_layers, d_model, num_heads, dff, 
                            target_vocab_size,max_pos_encoding, rate)

        self.final_layer = tf.keras.layers.Dense(target_vocab_size)
        
    def call(self, inp, tar, training,look_ahead_mask=None, dec_padding_mask=None,enc_padding_mask=None):

        enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)
        
        # dec_output.shape == (batch_size, tar_seq_len, d_model)
        dec_output, attention_weights = self.decoder(
            tar, enc_output, training, look_ahead_mask, dec_padding_mask)
        
        final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
        
        return final_output, attention_weights

# %%
model = Transformer(num_layer,d_model,num_heads,dff,row_size,col_size,target_vocab_size,max_pos_encoding=target_vocab_size,rate=dropout_rate)
model.load_weights('Online References/Online Code (AV)/Image-Captioning-main/Transformer/image_caption_transformer_45.h5')

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
